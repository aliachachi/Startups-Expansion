# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Inspecting Data

# %%
startup = pd.read_excel(r'C:\Users\Surface\Apple\Desktop\Data Analytics Portfolio\1- Python\startup-expansion.xlsx')
startup
# Out:
#      Store ID              City           State Sales Region New Expansion  \
# 0           1            Peoria         Arizona     Region 2           Old
# 1           2           Midland           Texas     Region 2           Old
# 2           3           Spokane      Washington     Region 2           Old
# 3           4            Denton           Texas     Region 2           Old
# 4           5     Overland Park          Kansas     Region 2           Old
# 5           6           Yonkers        New York     Region 1           Old
# 6           7        Birmingham         Alabama     Region 1           Old
# 7           8           Antioch      California     Region 2           Old
# 8           9         Worcester   Massachusetts     Region 1           Old
# 9          10         Rochester        New York     Region 1           Old
# 10         11            Rialto      California     Region 2           Old
# ...

# %% [markdown]
# ### Show all the data

# %%
pd.set_option('display.max_rows', startup.shape[0])
startup
# Out:
#      Store ID              City           State Sales Region New Expansion  \
# 0           1            Peoria         Arizona     Region 2           Old
# 1           2           Midland           Texas     Region 2           Old
# 2           3           Spokane      Washington     Region 2           Old
# 3           4            Denton           Texas     Region 2           Old
# 4           5     Overland Park          Kansas     Region 2           Old
# 5           6           Yonkers        New York     Region 1           Old
# 6           7        Birmingham         Alabama     Region 1           Old
# 7           8           Antioch      California     Region 2           Old
# 8           9         Worcester   Massachusetts     Region 1           Old
# 9          10         Rochester        New York     Region 1           Old
# 10         11            Rialto      California     Region 2           Old
# ...

# %%
startup.columns
# Out:
# Index(['Store ID', 'City', 'State', 'Sales Region', 'New Expansion',
#        'Marketing Spend', 'Revenue'],
#       dtype='object')

# %%
startup.shape
# Out:
# (150, 7)

# %%
# columns * Rows
startup.size
# Out:
# 1050

# %%
# see if there is missing data(percentage)
for i in startup.columns:
    percent_miss = np.mean(startup[i].isnull())
    print('{} - {}%'.format(i,percent_miss))
# Out:
# Store ID - 0.0%
# City - 0.0%
# State - 0.0%
# Sales Region - 0.0%
# New Expansion - 0.0%
# Marketing Spend - 0.0%
# Revenue - 0.0%

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
# Statical describe
startup[['Marketing Spend','Revenue']].describe().round(2)
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %% [markdown]
# # Preprocessing Data

# %%
startup['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
# number of cities
len(startup['City'].unique())
# Out:
# 149

# %%
# number of stores of each city
startup['City'].value_counts()
# Out:
# Rochester           2
# Killeen             1
# Wichita Falls       1
# Naperville          1
# Clovis              1
# Billings            1
# Surprise            1
# Coral Springs       1
# Visalia             1
# Peoria              1
# Gainesville         1
# Orange              1
# Richardson          1
# South Bend          1
# Fayetteville        1
# Sioux Falls         1
# Grand Prairie       1
# Stamford            1
# Dayton              1
# Aurora              1
# Knoxville           1
# Elgin               1
# New Haven           1
# Pueblo              1
# Costa Mesa          1
# Garden Grove        1
# Fort Lauderdale     1
# North Charleston    1
# Cambridge           1
# Greeley             1
# Gresham             1
# Amarillo            1
# High Point          1
# Vista               1
# Tacoma              1
# Mesquite            1
# Augusta             1
# West Palm Beach     1
# Renton              1
# Topeka              1
# McAllen             1
# ...

# %%
startup['State'].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
# number of states
len(startup['State'].unique())
# Out:
# 35

# %%
# number of stores in each state desc
startup['State'].value_counts()
# Out:
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: State, dtype: int64

# %%
# regions
startup['Sales Region'].unique()
# Out:
# array(['Region 2', 'Region 1'], dtype=object)

# %%
# number of stors in each region 
startup['Sales Region'].value_counts()
# Out:
# Region 2    86
# Region 1    64
# Name: Sales Region, dtype: int64

# %%
# new expansion
startup['New Expansion'].unique()
# Out:
# array(['Old', 'New'], dtype=object)

# %%
# number of stores of each New Expansion
startup['New Expansion'].value_counts()
# Out:
# Old    140
# New     10
# Name: New Expansion, dtype: int64

# %%
# show if there is row duplicated
startup.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploring Data

# %%
# random rows 
startup.sample(10)
# Out:
#      Store ID            City        State Sales Region New Expansion  \
# 44         45  San Bernardino   California     Region 2           Old
# 149       150   Thousand Oaks   California     Region 2           New
# 31         32    Grand Rapids     Michigan     Region 1           Old
# 142       143          Joliet     Illinois     Region 1           New
# 117       118        Bellevue   Washington     Region 2           Old
# 86         87        Amarillo        Texas     Region 2           Old
# 103       104         Killeen        Texas     Region 2           Old
# 75         76          Topeka       Kansas     Region 2           Old
# 17         18         Fontana   California     Region 2           Old
# 110       111        Stamford  Connecticut     Region 1           Old
#
#      Marketing Spend  Revenue
# 44              3399    59870
# 149             2431    40141
# 31              2808    65475
# 142             3279    48315
# 117             2542    40462
# ...

# %%
startup['Sales Region'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### The top 10 old states has top revenue

# %%
startup[startup['New Expansion'] == 'Old'].groupby(['State']).sum()['Revenue'].nlargest(10)
# Out:
# State
# California     1362468
# Texas           554964
# Florida         479023
# Washington      298013
# Alabama         221025
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Michigan        147759
# Name: Revenue, dtype: int64

# %% [markdown]
# ### The top 5 New states has top revenue

# %%
startup[startup['New Expansion'] == 'New'].groupby(['State']).sum()['Revenue'].nlargest(5)
# Out:
# State
# California    141883
# Illinois       91692
# Texas          85605
# Tennessee      55357
# Arizona        48954
# Name: Revenue, dtype: int64

# %%
startup['PROFIT'] = startup['Revenue']-startup['Marketing Spend']

# %% [markdown]
# ### Return on Marketing spend

# %%
startup['ROMS'] = round(startup['PROFIT']/startup['Marketing Spend']*100,2)
startup['ROMS%'] = round(startup['PROFIT']/startup['Marketing Spend'],2)

startup.head()
# Out:
#    Store ID           City       State Sales Region New Expansion  \
# 0         1         Peoria     Arizona     Region 2           Old
# 1         2        Midland       Texas     Region 2           Old
# 2         3        Spokane  Washington     Region 2           Old
# 3         4         Denton       Texas     Region 2           Old
# 4         5  Overland Park      Kansas     Region 2           Old
#
#    Marketing Spend  Revenue  PROFIT     ROMS  ROMS%
# 0             2601    48610   46009  1768.90  17.69
# 1             2727    45689   42962  1575.43  15.75
# 2             2768    49554   46786  1690.25  16.90
# 3             2759    38284   35525  1287.60  12.88
# 4             2869    59887   57018  1987.38  19.87

# %% [markdown]
# ### Import the data into csv file

# %%
startup.to_csv('startups.csv')
